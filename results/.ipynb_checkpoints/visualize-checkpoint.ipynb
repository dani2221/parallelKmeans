# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
data_cen = []
for i in range(1,17):
    obj = {}
    folder = 'outputs-centroids/'
    if f'serial_{i}.json' in os.listdir(folder):
        f = open(f'{folder}serial_{i}.json')
        data = json.load(f)
        obj['serial'] = data[-1]['time'] * 5
    if f'centroid_{i}.json' in os.listdir(folder):
        f = open(f'{folder}centroid_{i}.json')
        data = json.load(f)
        obj['centroid'] = data[-1]['time'] * 5
    if f'batch_{i}.json' in os.listdir(folder):
        f = open(f'{folder}batch_{i}.json')
        data = json.load(f)
        obj['batch'] = data[-1]['time'] * 5
    if f'centroidbatch_{i}-2.json' in os.listdir(folder):
        f = open(f'{folder}centroidbatch_{i}-2.json')
        data = json.load(f)
        obj['cb-2'] = data[-1]['time'] * 5
    if f'centroidbatch_{i}-3.json' in os.listdir(folder):
        f = open(f'{folder}centroidbatch_{i}-3.json')
        data = json.load(f)
        obj['cb-3'] = data[-1]['time'] * 5
    if f'centroidbatch_{i}-4.json' in os.listdir(folder):
        f = open(f'{folder}centroidbatch_{i}-4.json')
        data = json.load(f)
        obj['cb-4'] = data[-1]['time'] * 5
    data_cen.append(obj)
data_cen
# Out:
# [{'serial': 144.09622192382812,
#   'centroid': 133.94636392593384,
#   'batch': 83.1677520275116,
#   'cb-2': 110.88066697120667,
#   'cb-3': 86.05747580528259,
#   'cb-4': 73.44867944717407},
#  {'cb-2': 109.47323083877563,
#   'cb-3': 88.3342444896698,
#   'cb-4': 68.94444108009338},
#  {'serial': 182.78567552566528,
#   'centroid': 134.46528792381287,
#   'batch': 83.29107284545898,
#   'cb-3': 107.75094985961914,
#   'cb-4': 94.8766541481018},
#  {'cb-2': 128.57975125312805,
#   'cb-3': 114.00628566741943,
#   'cb-4': 91.45377278327942},
#  {'serial': 193.3203899860382,
#   'centroid': 140.4871702194214,
#   'batch': 90.08709192276001,
#   'cb-3': 128.31462860107422},
#  {'cb-2': 165.11656761169434},
#  {'serial': 194.9445366859436,
#   'centroid': 160.82897782325745,
#   'batch': 87.44945287704468},
#  {'cb-2': 190.0614368915558},
#  {'serial': 219.7446358203888,
#   'centroid': 180.18110632896423,
#   'batch': 89.19601917266846},
#  {},
#  {'serial': 246.90173387527466,
#   'centroid': 203.96233201026917,
#   'batch': 93.0655026435852},
#  {},
#  {'serial': 251.0483992099762,
#   'centroid': 205.37678480148315,
#   'batch': 93.29763889312744},
#  {},
#  {'serial': 262.9006564617157,
#   'centroid': 234.02145743370056,
#   'batch': 102.58809804916382},
#  {'serial': 260.89590191841125,
#   'centroid': 239.417804479599,
#   'batch': 106.46799325942993}]

# %%
data_sp = []
for i in [0.01, 0.1, 0.25, 0.5, 0.75, 1]:
    obj = {}
    folder = 'outputs-data/'
    if f'serial_5_{i}.json' in os.listdir(folder):
        f = open(f'{folder}serial_5_{i}.json')
        data = json.load(f)
        obj['serial'] = data[-1]['time'] * 5
    if f'centroid_5_{i}.json' in os.listdir(folder):
        f = open(f'{folder}centroid_5_{i}.json')
        data = json.load(f)
        obj['centroid'] = data[-1]['time'] * 5
    if f'batch_5_{i}.json' in os.listdir(folder):
        f = open(f'{folder}batch_5_{i}.json')
        data = json.load(f)
        obj['batch'] = data[-1]['time'] * 5
    if f'centroidbatch_5-2_{i}.json' in os.listdir(folder):
        f = open(f'{folder}centroidbatch_5-2_{i}.json')
        data = json.load(f)
        obj['cb-2'] = data[-1]['time'] * 5
    if f'centroidbatch_5-3_{i}.json' in os.listdir(folder):
        f = open(f'{folder}centroidbatch_5-3_{i}.json')
        data = json.load(f)
        obj['cb-3'] = data[-1]['time'] * 5
    data_sp.append(obj)
data_sp
# Out:
# [{'serial': 1.7336153984069824,
#   'centroid': 1.1598587036132812,
#   'batch': 2.01227068901062,
#   'cb-2': 3.775423765182495,
#   'cb-3': 3.723210096359253},
#  {'serial': 16.60181164741516,
#   'centroid': 11.923662424087524,
#   'batch': 6.349764585494995,
#   'cb-2': 15.881447792053223,
#   'cb-3': 12.853983640670776},
#  {'serial': 42.13858127593994,
#   'centroid': 30.09114384651184,
#   'batch': 16.545166969299313,
#   'cb-2': 40.42721390724182,
#   'cb-3': 26.278038024902344},
#  {'serial': 87.67767548561096,
#   'centroid': 58.63272666931152,
#   'batch': 31.951415538787842,
#   'cb-2': 83.30251336097717,
#   'cb-3': 51.14604473114014},
#  {'serial': 127.04947471618652,
#   'centroid': 91.24484896659851,
#   'batch': 50.39634037017822,
#   'cb-2': 120.142502784729,
#   'cb-3': 80.07212996482849},
#  {'serial': 176.42484307289124,
#   'centroid': 118.22425842285156,
#   'batch': 65.51932001113892,
#   'cb-2': 162.94591188430786,
#   'cb-3': 99.30954098701477}]

# %%
df_cen = pd.DataFrame(data_cen).interpolate(limit=1)
df_sp = pd.DataFrame(index=['1%', '10%', '25%', '50%', '75%', '100%'], data=data_sp).interpolate(limit=1)

# %%
df_cen
# Out:
#         serial    centroid       batch        cb-2        cb-3       cb-4
# 0   144.096222  133.946364   83.167752  110.880667   86.057476  73.448679
# 1   163.440949  134.205826   83.229412  109.473231   88.334244  68.944441
# 2   182.785676  134.465288   83.291073  119.026491  107.750950  94.876654
# 3   188.053033  137.476229   86.689082  128.579751  114.006286  91.453773
# 4   193.320390  140.487170   90.087092  146.848159  128.314629  91.453773
# 5   194.132463  150.658074   88.768272  165.116568  128.314629        NaN
# 6   194.944537  160.828978   87.449453  177.589002         NaN        NaN
# 7   207.344586  170.505042   88.322736  190.061437         NaN        NaN
# 8   219.744636  180.181106   89.196019  190.061437         NaN        NaN
# 9   233.323185  192.071719   91.130761         NaN         NaN        NaN
# 10  246.901734  203.962332   93.065503         NaN         NaN        NaN
# 11  248.975067  204.669558   93.181571         NaN         NaN        NaN
# 12  251.048399  205.376785   93.297639         NaN         NaN        NaN
# 13  256.974528  219.699121   97.942868         NaN         NaN        NaN
# 14  262.900656  234.021457  102.588098         NaN         NaN        NaN
# 15  260.895902  239.417804  106.467993         NaN         NaN        NaN

# %%
ax = df_cen.plot.line()
ax.set_xlabel('# of centroids')
ax.set_ylabel('time (s)')
plt.show()

# %%
ax = df_sp.plot.line()
ax.set_xlabel('# of centroids')
ax.set_ylabel('time (s)')
plt.show()
